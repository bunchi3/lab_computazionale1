# %% [markdown]
# # Gauss-Legendre & double exponential

# %%
using Plots
using SpecialFunctions
using LaTeXStrings
include("c:\\ALL\\Stefano\\Bicocca\\3terzo_anno\\lab_comp\\lab_computazionale1\\librerie\\integration.jl")
function autosave(fig, filename)
    path = "C:\\ALL\\Stefano\\Bicocca\\3terzo_anno\\lab_comp\\lab_computazionale1\\relazione\\immagini"
    savefig(fig, joinpath(path, filename))
end

# %% [markdown]
# La considerazione è che qui con questi metodi si riesce a integrare anche su funzioni chhe davano problemi
# Si nota che ora gauss, dato che è in presensza di singolarità, ha convergenza esponenziale.

# %% [markdown]
# For each integral, compute approximations using the Gauss-Legendre quadrature rule with $n=4,6,8,\ldots,60$, and the proper double-exponential quadrature rule with $N=n/2$. Plot the errors as functions of $n$ on a semi-log scale.

# %%
n = Int[i for i in 4:2:60]
N = Int.(n ./ 2)

f1 = x -> sqrt(x)log(x)
f2 = x -> sqrt(1-x^2)
f3 = x -> (log(x))^2
f4 = x -> log(cos(x))
f5 = x -> sqrt(tan(x))

I1 = -4.0/9.0
I2 = pi/4.0
I3 = 2.0
I4 = -pi/2.0 * log(2)
I5 = pi/sqrt(2.0)

# %% [markdown]
# **(a)** $\displaystyle \int_0^1 \sqrt{x} \log(x) \, dx = -\frac{4}{9}$

# %%
a=0.0
b=1.0
I_gauss = []
I_de = []
for i in 1:1:length(n)
    push!(I_gauss, IntegralGaussLegendre(f1, n[i]; a, b))
end
for i in 1:1:length(N)
    push!(I_de, Integral_DE(f1, N[i], a, b))    
end

g_err = abs.(I_gauss .- I1)
de_err = abs.(I_de .- I1)
g_err = [x <= eps() ? eps() : x for x in g_err]     #I need to correct them because the log graph wouldn't accept zeros
de_err = [x <= eps() ? eps() : x for x in de_err]

fig = plot(figsize=(800, 600),
           xlabel=L"n", ylabel=L"Error",
           framestyle=:box,
           grid=true, gridalpha=0.5,
           yscale = :log10,
           xticks = [n[i] for i in 1:2:length(n)], yticks = [10.0^i for i in -18:2:0],
           legend = :topright
          )

plot!(fig, n, g_err,
      label = L"Gauss-Legendre",
      color= :navy,
      marker = :circle,
      lw = 2.5,
     ) 

plot!(fig, n, de_err,
      label = L"Double\ exponential",
      color= :darkorange,
      marker = :circle,
      lw = 2.5,
     ) 

autosave(fig, "5431.pdf")
display(fig)

# %% [markdown]
# **(b)** $\displaystyle \int_0^1 \sqrt{1-x^2}\,\, dx = \frac{\pi}{4}$

# %%
a=0.0
b=1.0
I_gauss = []
I_de = []
for i in 1:1:length(n)
    push!(I_gauss, IntegralGaussLegendre(f2, n[i]; a, b))
end
for i in 1:1:length(N)
    push!(I_de, Integral_DE(f2, N[i], a, b))    
end

g_err = abs.(I_gauss .- I2)
de_err = abs.(I_de .- I2)
g_err = [x <= eps() ? eps() : x for x in g_err]     #I need to correct them because the log graph wouldn't accept zeros
de_err = [x <= eps() ? eps() : x for x in de_err]

fig = plot(figsize=(800, 600),
           xlabel=L"n", ylabel=L"Error",
           framestyle=:box,
           grid=true, gridalpha=0.5,
           yscale = :log10,
           xticks = [n[i] for i in 1:2:length(n)], yticks = [10.0^i for i in -18:2:0],
           legend = :topright
          )

plot!(fig, n, g_err,
      label = L"Gauss-Legendre",
      color= :navy,
      marker = :circle,
      lw = 2.5,
     ) 

plot!(fig, n, de_err,
      label = L"Double\ exponential",
      color= :darkorange,
      marker = :circle,
      lw = 2.5,
     ) 

autosave(fig, "5432.pdf")
display(fig)

# %% [markdown]
# **(c)** $\displaystyle\int_{0}^1 (\log x)^2\, dx = 2$ \
# The lower bound of integration is considered $\epsilon_{mach}$ because it would be a singularity

# %%
a=eps()
b=1.0
I_gauss = []
I_de = []
for i in 1:1:length(n)
    push!(I_gauss, IntegralGaussLegendre(f3, n[i]; a, b))
end
for i in 1:1:length(N)
    push!(I_de, Integral_DE(f3, N[i], a, b))    
end

g_err = abs.(I_gauss .- I3)
de_err = abs.(I_de .- I3)
g_err = [x <= eps() ? eps() : x for x in g_err]     #I need to correct them because the log graph wouldn't accept zeros
de_err = [x <= eps() ? eps() : x for x in de_err]

fig = plot(figsize=(800, 600),
           xlabel=L"n", ylabel=L"Error",
           framestyle=:box,
           grid=true, gridalpha=0.5,
           yscale = :log10,
           xticks = [n[i] for i in 1:2:length(n)], yticks = [10.0^i for i in -18:2:0],
           legend = :topright
          )

plot!(fig, n, g_err,
      label = L"Gauss-Legendre",
      color= :navy,
      marker = :circle,
      lw = 2.5,
     ) 

plot!(fig, n, de_err,
      label = L"Double\ exponential",
      color= :darkorange,
      marker = :circle,
      lw = 2.5,
     ) 

autosave(fig, "5433.pdf")
display(fig)

# %% [markdown]
# **(d)** $\displaystyle\int_{0}^{\pi/2} \log(\cos(x))\, dx = -\frac{\pi}{2}\log(2)$

# %%
a=0
b=pi/2
I_gauss = []
I_de = []
for i in 1:1:length(n)
    push!(I_gauss, IntegralGaussLegendre(f4, n[i]; a, b))
end
for i in 1:1:length(N)
    push!(I_de, Integral_DE(f4, N[i], a, b))    
end

g_err = abs.(I_gauss .- I4)
de_err = abs.(I_de .- I4)
g_err = [x <= eps() ? eps() : x for x in g_err]     #I need to correct them because the log graph wouldn't accept zeros
de_err = [x <= eps() ? eps() : x for x in de_err]

fig = plot(figsize=(800, 600),
           xlabel=L"n", ylabel=L"Error",
           framestyle=:box,
           grid=true, gridalpha=0.5,
           yscale = :log10,
           xticks = [n[i] for i in 1:2:length(n)], yticks = [10.0^i for i in -18:2:0],
           legend = :topright
          )

plot!(fig, n, g_err,
      label = L"Gauss-Legendre",
      color= :navy,
      marker = :circle,
      lw = 2.5,
     ) 

plot!(fig, n, de_err,
      label = L"Double\ exponential",
      color= :darkorange,
      marker = :circle,
      lw = 2.5,
     ) 

autosave(fig, "5434.pdf")
display(fig)

# %% [markdown]
# **(e)** $\displaystyle\int_{0}^{\pi/2} \sqrt{\tan(x)}\, dx = \dfrac{\pi}{\sqrt{2}}$

# %%
a=0
b=pi/2
I_gauss = []
I_de = []
for i in 1:1:length(n)
    push!(I_gauss, IntegralGaussLegendre(f5, n[i]; a, b))
end
for i in 1:1:length(N)
    push!(I_de, Integral_DE(f5, N[i], a, b))    
end

g_err = abs.(I_gauss .- I5)
de_err = abs.(I_de .- I5)
g_err = [x <= eps() ? eps() : x for x in g_err]     #I need to correct them because the log graph wouldn't accept zeros
de_err = [x <= eps() ? eps() : x for x in de_err]

fig = plot(figsize=(800, 600),
           xlabel=L"n", ylabel=L"Error",
           framestyle=:box,
           grid=true, gridalpha=0.5,
           yscale = :log10,
           xticks = [n[i] for i in 1:2:length(n)], yticks = [10.0^i for i in -18:2:0],
           legend = :topright
          )

plot!(fig, n, g_err,
      label = L"Gauss-Legendre",
      color= :navy,
      marker = :circle,
      lw = 2.5,
     ) 

plot!(fig, n, de_err,
      label = L"Double\ exponential",
      color= :darkorange,
      marker = :circle,
      lw = 2.5,
     ) 

autosave(fig, "5435.pdf")
display(fig)

# %% [markdown]
# Morale: No singolarità = gauss legendre, ha convergenza più rapida \
# singolarità = quadratura esponenziale, ha convergenza non molto rapida ma riesce a integrare le singolarità agli estremi
# \
# Per integrare in più dimensioni si fanno integrali uno alla volta, una dimensione alla volta. Oltre a un certo numero di dimensioni si usano i metodi MonteCarlo, perchè in questi metodi non importa il numero di dimensioni
